# %%
import torch

# %%
x = torch.tensor(2.3, requires_grad=True)
y = x**2

# %%
x
# Out:
# tensor(2.3000, requires_grad=True)

# %%
y
# Out:
# tensor(5.2900, grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.6000)

# %%
x = torch.rand(3, requires_grad=True)

# %%
x
# Out:
# tensor([0.3746, 0.9672, 0.1605], requires_grad=True)

# %%
y = (x**2).mean()

# %%
y
# Out:
# tensor(0.3672, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.2497, 0.6448, 0.1070])

# %%
x = torch.rand(4, requires_grad=True)

# %%
y = x + 2
y
# Out:
# tensor([2.3689, 2.2929, 2.4611, 2.2532], grad_fn=<AddBackward0>)

# %%
z = torch.sigmoid(y)

# %%
z
# Out:
# tensor([0.9144, 0.9083, 0.9214, 0.9049], grad_fn=<SigmoidBackward0>)

# %%
x.grad

# %%
x
# Out:
# tensor([0.3689, 0.2929, 0.4611, 0.2532], requires_grad=True)

# %%
y
# Out:
# tensor([2.3689, 2.2929, 2.4611, 2.2532], grad_fn=<AddBackward0>)

# %%
y = torch.rand(3, requires_grad=True)

# %%
y
# Out:
# tensor([0.6299, 0.6367, 0.9641], requires_grad=True)

# %%
y.requires_grad_(False)
# Out:
# tensor([0.6299, 0.6367, 0.9641])

# %%
y
# Out:
# tensor([0.6299, 0.6367, 0.9641])

# %%
y = torch.rand(3, requires_grad=True)

# %%
y.
