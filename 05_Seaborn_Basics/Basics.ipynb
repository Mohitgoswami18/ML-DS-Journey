# %% [markdown]
# ## Seaborn

# %% [markdown]
# Seaborn is a data visualization library built on top of Matplotlib.
#
# It makes it easier to create complex and attractive plots using simple commands.
#
# It works directly with Pandas DataFrames.

# %%
import seaborn as sns
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

sns.set_style('dark')

# %% [markdown]
# Seaborn have inbuilt datasets to work upon

# %%
tips = sns.load_dataset('tips')
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# Overall there are 2 types of plots
# 1. Quantitative Plots
# 2. Qualitative Plots

# %% [markdown]
# ### Quantitative

# %%
#  1. histplot / distplot -> dist will be depreciated in later versions
sns.histplot(tips['total_bill'], bins=30, kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.scatterplot(x=tips['total_bill'], y=tips['tip'], hue=tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x=tips['total_bill'], y=tips['tip'], hue=tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.violinplot(x=tips['size'], y=tips['total_bill'])
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %% [markdown]
# ### Box Plot (5 number summary)

# %%
arr = [2,3,3,4,12,20,22,22,22,23,25,25,250]
q1 = np.percentile(arr, 25)
q3 = np.percentile(arr, 75)
IQR = q3 - q1

upperFence = q3 + 1.5 * IQR
lowerFence = q1 - 1.5 * IQR

lis = []
for i in arr:
    if i >= lowerFence and i <= upperFence:
        lis.append(i)

sns.boxplot(x = lis)
# Out:
# <Axes: >

# %%
sns.pairplot(tips, kind='reg')
sns.set_style('dark')

# %%
sns.jointplot(x=tips['total_bill'], y=tips['tip'], kind='reg')

# %% [markdown]
# ### Qualitative

# %%
sns.barplot(x=tips['sex'], y=tips['total_bill'])
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='smoker', data=tips)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %% [markdown]
# ### MATRIX PLOT

# %%
pivot_data = tips.pivot_table(values='total_bill', columns='sex', index='tip')
sns.heatmap(pivot_data)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17964\4263889594.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_data = tips.pivot_table(values='total_bill', columns='sex', index='tip')
# <Axes: xlabel='sex', ylabel='tip'>

# %%
pivot = tips.pivot_table(values="tip", index="day", columns="sex", aggfunc="mean")
sns.heatmap(pivot)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17964\4103495949.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = tips.pivot_table(values="tip", index="day", columns="sex", aggfunc="mean")
# <Axes: xlabel='sex', ylabel='day'>

# %% [markdown]
# ### Using Seaborn With Matplotlib

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex")
plt.title("Total Bill vs Tip")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.grid(True)
plt.savefig('sample.png')
plt.show()
